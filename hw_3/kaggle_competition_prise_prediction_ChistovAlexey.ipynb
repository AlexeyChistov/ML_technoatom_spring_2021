# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Небольшой класс для препроцессинга

# %%
class SimpleDataPreprocessing(object):
    def __init__(
            self,
            df,
            list_of_drop_columns=None,
            metro_dist_fill_meth='most_common',
    ):
        self.df = df
        self.date_to_numerical()
        self.metro_dist_fill_meth = metro_dist_fill_meth
        self.list_of_drop_columns = list_of_drop_columns
        self.replace_nan_metro_dist(self.metro_dist_fill_meth)
        self.replace_nan()

        if self.drop_columns is not None:
            self.drop_columns(self.list_of_drop_columns)

    def date_to_numerical(self):
        """
        Замена категориальный данных численными.
        Столбец 'date'
        Заменяем данные на количество месяцев, начиная с первой даты
        """
        # self.df['date'] = pd.to_datetime(self.df['date']).sub(pd.Timestamp(self.df.date[0])).dt.days // 30
        self.df['date'] = pd.to_datetime(self.df['date']).dt.month + \
                          12 * (pd.to_datetime(self.df['date']).dt.year - min(pd.to_datetime(self.df['date']).dt.year))

    def replace_nan_metro_dist(self, fill_type):
        if fill_type == 'mean':
            self.df.loc[pd.isnull(self.df['metro_dist']), 'metro_dist'] = round(self.df['metro_dist'].mean())
            return
        if fill_type == 'most_common':
            self.df.loc[pd.isnull(self.df['metro_dist']), 'metro_dist'] = \
                train_data['metro_dist'].value_counts().index.tolist()[0]
            return

    def replace_nan(self):
        """
        Заменяем пропуски NaN
        """
        # for column in self.df:
        #     self.df.loc[pd.isnull(self.df[column]), column] = \
        #         train_data[column].value_counts().index.tolist()[0]
        for column in self.df:
            self.df.loc[pd.isnull(self.df[column]), column] = -1

    def drop_nan_lines(self, columns):
        for column in columns:
            self.df = self.df.drop(self.df[pd.isnull(self.df[column])].index)

    def drop_columns(self, columns):
        """
        Удаляем колонки
        """
        self.df.drop(columns=columns, inplace=True)

    def return_preprocessed_df(self):
        return self.df

# %%
train_data = pd.read_csv('./Train.csv', delimiter=',')    # Train data
test_data = pd.read_csv('./Test.csv', delimiter=',')    # Test data

# %% [markdown]
# # Построим гистограммы по столбцам

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data.price.values, hist=True, kde=False, 
             bins=int(180/2), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(1 / preprocessed_train_data.metro_dist, hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='metro_dist'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data.area, hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'b'})
# Out:
# <AxesSubplot:xlabel='area'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data.date, hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data['kw2'], hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='kw2'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data['kw1'], hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='kw1'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data['kw3'], hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='kw3'>

# %%
plt.figure(figsize=(20, 10))
sns.distplot(preprocessed_train_data['kw4'], hist=True, kde=False,
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='kw4'>

# %% [markdown]
# <font size=3>Можно заметить, что признаки kw1, kw3 - kw13 в основном забиты нулями, и скорее всего их нужно дропнуть.

# %% [markdown]
# # Построим зависимости некоторых признаков от цены

# %%
plt.figure(figsize=(20, 10))
plt.scatter(preprocessed_train_data.price, preprocessed_train_data.metro_dist, color = 'blue')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(preprocessed_train_data.price, preprocessed_train_data.floor, color = 'blue')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(preprocessed_train_data.price, preprocessed_train_data.build_tech, color = 'blue')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(preprocessed_train_data.price, preprocessed_train_data.g_lift, color = 'blue')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(preprocessed_train_data.price, preprocessed_train_data.area, color = 'blue')

# %% [markdown]
# <font size=3>Нашли выбросы: нереалистичное соотношение $\frac{цена}{площадь}$. Необходимо подчистить датасет. Как видно из рисунка, они имеют значение цены = константе. Найдем это значение, затем подчистим.

# %%
df = preprocessed_train_data[preprocessed_train_data.area > np.log(150)]
sorted_df = df.sort_index().sort_values('price', kind='mergesort')
print(sorted_df.loc[:, ['area', 'price']].head(20))
# Out:
#            area      price
# 201    5.204007  1000000.0
# 7438   5.209486  1000000.0
# 18735  5.209486  1000000.0
# 20575  5.153292  1000000.0
# 30586  5.209486  1000000.0
# 31145  5.198497  1000000.0
# 39679  5.204007  1000000.0
# 42671  5.153292  1000000.0
# 43216  5.209486  1000000.0
# 44119  5.117994  1000000.0
# 46065  5.209486  1000000.0
# 46437  5.375278  1000000.0
# 54919  5.370638  1000000.0
# 55879  5.117994  1000000.0
# 56840  5.209486  1000000.0
# 61242  5.209486  1000000.0
# 69038  5.209486  1000000.0
# 70898  5.209486  1000000.0
# 71174  5.209486  1000000.0
# 71264  5.209486  1000000.0

# %% [markdown]
# <font size = 3>Предварительный анализ данных можно сделать утверждение, что:
#
#     -почти все признаки являются категориальными (кроме площади)
#     -некоторые призныки спокойно можно удалить
#     -были обнаружены шумовые значения.
# <font>

# %%
# Удаляемые индексы
deleting_indexes = [
    0,  # id
    # 1,  # date
    # 2,  # street_id
    # 3,  # build_tech
    # 4,  # floor
    # 5,  # area
    # 6,  # rooms
    # 7,  # balcon
    # 8,  # metro_dist
    # 9,  # g_lift
    # 10,  # n_photos
    11,  # kw1
    # 12,  # kw2
    13,  # kw3
    14,  # kw4
    15,  # kw5
    16,  # kw6
    17,  # kw7
    18,  # kw8
    19,  # kw9
    20,  # kw10
    21,  # kw11
    22,  # kw12
    23,  # kw13
]


deleting_columns = list()
for i, column in enumerate(train_data):
    if i in deleting_indexes:
        deleting_columns.append(column)

# %%
# Создаем экземпляры класса, предобрабатываем данные
TestData = SimpleDataPreprocessing(test_data, list_of_drop_columns=deleting_columns,)
TrainData = SimpleDataPreprocessing(train_data, list_of_drop_columns=deleting_columns,)

preprocessed_test_data = TestData.return_preprocessed_df()
preprocessed_train_data = TrainData.return_preprocessed_df()

# Удаляем шум
preprocessed_train_data = \
    preprocessed_train_data.drop(preprocessed_train_data[(preprocessed_train_data.price == 1e6)].index)

y_train = preprocessed_train_data.price.values.astype(int)
preprocessed_train_data.drop(columns=['price'], inplace=True)

dict_of_columns = dict()
for i, column in enumerate(preprocessed_train_data):
    dict_of_columns[column] = i
print(dict_of_columns)


# Можно увидеть из графика, что точки ложатся не совсем линейно (площадь от цены)
# пусть будет корень, мб логарифм был бы и лучше
preprocessed_train_data['area'] = np.sqrt(preprocessed_train_data['area'])
preprocessed_test_data['area'] = np.sqrt(preprocessed_test_data['area'])


# Переводим все колонки предобработанного датафрейма в int, кроме площади (для catboost'а)
for column in preprocessed_train_data:
    if column not in ['area']:
        preprocessed_train_data[column] = preprocessed_train_data[column].values.astype(int)

for column in preprocessed_test_data:
    if column not in ['area']:
        preprocessed_test_data[column] = preprocessed_test_data[column].values.astype(int)
# Out:
# {'date': 0, 'street_id': 1, 'build_tech': 2, 'floor': 3, 'area': 4, 'rooms': 5, 'balcon': 6, 'metro_dist': 7, 'g_lift': 8, 'n_photos': 9, 'kw2': 10}

# %%
# Проводим сплит для предварительной оценки датасета
X_train_train, X_train_test, y_train_train, y_train_test = \
    train_test_split(
        preprocessed_train_data, y_train,
        test_size=0.25,
    )

# %% [markdown]
# # CatBoostRegressor

# %%
# Объявляем, какие фичи будут категориальными
cat_features = [
    # dict_of_columns['date'],
    dict_of_columns['street_id'],
    dict_of_columns['build_tech'],
    dict_of_columns['floor'],
    # dict_of_columns['area'],
    dict_of_columns['rooms'],
    dict_of_columns['balcon'],
    dict_of_columns['metro_dist'],
    dict_of_columns['g_lift'],
    dict_of_columns['n_photos'],
    # dict_of_columns['kw1'],
    dict_of_columns['kw2'],
    # dict_of_columns['kw3'],
    # dict_of_columns['kw4'],
    # dict_of_columns['kw5'],
    # dict_of_columns['kw6'],
    # dict_of_columns['kw7'],
    # dict_of_columns['kw8'],
    # dict_of_columns['kw9'],
    # dict_of_columns['kw10'],
    # dict_of_columns['kw11'],
    # dict_of_columns['kw12'],
    # dict_of_columns['kw13']
]

# Объявляем регрессор
cb_regressor = CatBoostRegressor(
    loss_function='RMSE',
    learning_rate=0.25,
    iterations=500,
    # num_leaves=20,
    bootstrap_type='MVS',
    max_depth=12,
    od_type='Iter'
)

# %%
print(f'cat_features:\n{cat_features}', X_train.shape)
cb_regressor.fit(X_train_train, y_train_train, cat_features=cat_features)
cb_predict = cb_regressor.predict(X_train_test)
print(mean_absolute_error(y_train_test, cb_predict))
# Out:
# cat_features:
# [1, 2, 3, 5, 6, 7, 8, 9, 10] (95998, 11)
# 0:	learn: 3026064.4641373	total: 371ms	remaining: 3m 5s
# 1:	learn: 2506422.0143335	total: 702ms	remaining: 2m 54s
# 2:	learn: 2121392.6837084	total: 983ms	remaining: 2m 42s
# 3:	learn: 1844339.2702687	total: 1.28s	remaining: 2m 38s
# 4:	learn: 1652384.4907799	total: 1.54s	remaining: 2m 32s
# 5:	learn: 1519676.0364330	total: 1.84s	remaining: 2m 31s
# 6:	learn: 1431084.3358360	total: 2.15s	remaining: 2m 31s
# 7:	learn: 1362963.4799235	total: 2.45s	remaining: 2m 30s
# 8:	learn: 1310005.9685245	total: 2.77s	remaining: 2m 31s
# 9:	learn: 1268801.1062921	total: 3.12s	remaining: 2m 32s
# 10:	learn: 1238507.1865657	total: 3.41s	remaining: 2m 31s
# 11:	learn: 1216000.6933770	total: 3.77s	remaining: 2m 33s
# 12:	learn: 1182506.7927507	total: 4.12s	remaining: 2m 34s
# 13:	learn: 1154165.5746514	total: 4.42s	remaining: 2m 33s
# 14:	learn: 1132310.5581514	total: 4.72s	remaining: 2m 32s
# 15:	learn: 1112889.0293751	total: 5.01s	remaining: 2m 31s
# 16:	learn: 1097358.4103628	total: 5.32s	remaining: 2m 31s
# 17:	learn: 1080292.3764180	total: 5.64s	remaining: 2m 30s
# 18:	learn: 1070598.9883883	total: 6s	remaining: 2m 32s
# 19:	learn: 1046499.3293636	total: 6.33s	remaining: 2m 31s
# 20:	learn: 1038220.8279212	total: 6.67s	remaining: 2m 32s
# 21:	learn: 1030294.1385152	total: 7.01s	remaining: 2m 32s
# 22:	learn: 1018940.8858874	total: 7.36s	remaining: 2m 32s
# 23:	learn: 1001392.1817364	total: 7.68s	remaining: 2m 32s
# 24:	learn: 995134.0236170	total: 8.11s	remaining: 2m 34s
# 25:	learn: 985654.5128878	total: 8.52s	remaining: 2m 35s
# 26:	learn: 973827.2875690	total: 8.83s	remaining: 2m 34s
# 27:	learn: 967346.1705458	total: 9.15s	remaining: 2m 34s
# 28:	learn: 959230.0138531	total: 9.52s	remaining: 2m 34s
# 29:	learn: 955430.9881100	total: 9.87s	remaining: 2m 34s
# 30:	learn: 948687.6576924	total: 10.2s	remaining: 2m 34s
# 31:	learn: 937130.7096151	total: 10.5s	remaining: 2m 34s
# 32:	learn: 927730.2301128	total: 10.9s	remaining: 2m 34s
# 33:	learn: 916553.8986459	total: 11.2s	remaining: 2m 33s
# 34:	learn: 906562.2288503	total: 11.7s	remaining: 2m 35s
# 35:	learn: 897235.4263335	total: 12.2s	remaining: 2m 37s
# 36:	learn: 892978.3807451	total: 12.5s	remaining: 2m 36s
# 37:	learn: 887197.6312392	total: 12.9s	remaining: 2m 36s
# 38:	learn: 879200.6643554	total: 13.2s	remaining: 2m 36s
# 39:	learn: 869660.9675974	total: 13.6s	remaining: 2m 36s
# 40:	learn: 862017.3329431	total: 13.9s	remaining: 2m 35s
# 41:	learn: 857922.6310969	total: 14.2s	remaining: 2m 34s
# 42:	learn: 856642.1974446	total: 14.3s	remaining: 2m 31s
# 43:	learn: 851955.2518621	total: 14.7s	remaining: 2m 32s
# 44:	learn: 844557.8626899	total: 15s	remaining: 2m 32s
# 45:	learn: 838334.7903333	total: 15.3s	remaining: 2m 31s
# 46:	learn: 835942.9024210	total: 15.8s	remaining: 2m 31s
# 47:	learn: 827216.5000972	total: 16.3s	remaining: 2m 33s
# 48:	learn: 824068.7482011	total: 16.6s	remaining: 2m 32s
# 49:	learn: 818608.1765797	total: 17s	remaining: 2m 32s
# 50:	learn: 816007.0108652	total: 17.3s	remaining: 2m 32s
# 51:	learn: 810997.2260914	total: 17.6s	remaining: 2m 31s
# 52:	learn: 806878.0145019	total: 17.8s	remaining: 2m 30s
# 53:	learn: 801523.1594897	total: 18.1s	remaining: 2m 29s
# 54:	learn: 796693.9152053	total: 18.5s	remaining: 2m 29s
# 55:	learn: 787469.2198394	total: 19s	remaining: 2m 30s
# 56:	learn: 784239.7993161	total: 19.4s	remaining: 2m 30s
# 57:	learn: 781984.2209989	total: 19.8s	remaining: 2m 30s
# 58:	learn: 778050.5079415	total: 20.1s	remaining: 2m 30s
# 59:	learn: 774212.6641557	total: 20.5s	remaining: 2m 30s
# 60:	learn: 769174.6161437	total: 20.8s	remaining: 2m 29s
# 61:	learn: 763642.6198469	total: 21.1s	remaining: 2m 28s
# 62:	learn: 759803.0364733	total: 21.5s	remaining: 2m 28s
# 63:	learn: 757085.9504285	total: 21.9s	remaining: 2m 28s
# 64:	learn: 753405.8583201	total: 22.2s	remaining: 2m 28s
# 65:	learn: 750680.0386119	total: 22.6s	remaining: 2m 28s
# 66:	learn: 745917.0714642	total: 22.9s	remaining: 2m 27s
# 67:	learn: 742479.1490660	total: 23.3s	remaining: 2m 27s
# 68:	learn: 739500.1662967	total: 23.6s	remaining: 2m 27s
# 69:	learn: 736043.1442875	total: 24.1s	remaining: 2m 28s
# 70:	learn: 732497.4240636	total: 24.4s	remaining: 2m 27s
# 71:	learn: 728488.2796279	total: 24.8s	remaining: 2m 27s
# 72:	learn: 726962.7034736	total: 25.1s	remaining: 2m 26s
# 73:	learn: 724921.0354012	total: 25.5s	remaining: 2m 26s
# 74:	learn: 720774.3009407	total: 25.8s	remaining: 2m 26s
# 75:	learn: 717572.3071963	total: 26s	remaining: 2m 25s
# 76:	learn: 713595.0524235	total: 26.3s	remaining: 2m 24s
# 77:	learn: 709964.8469113	total: 26.7s	remaining: 2m 24s
# 78:	learn: 705844.8408337	total: 27s	remaining: 2m 24s
# 79:	learn: 701761.9870357	total: 27.4s	remaining: 2m 23s
# 80:	learn: 698598.6490659	total: 27.7s	remaining: 2m 23s
# 81:	learn: 695727.7554749	total: 28s	remaining: 2m 22s
# 82:	learn: 691997.1087482	total: 28.4s	remaining: 2m 22s
# 83:	learn: 689046.5399929	total: 28.8s	remaining: 2m 22s
# 84:	learn: 685492.2116108	total: 29.1s	remaining: 2m 22s
# 85:	learn: 682780.1413414	total: 29.4s	remaining: 2m 21s
# 86:	learn: 680376.7919930	total: 29.7s	remaining: 2m 20s
# 87:	learn: 678017.9634755	total: 30s	remaining: 2m 20s
# 88:	learn: 674123.8445165	total: 30.4s	remaining: 2m 20s
# 89:	learn: 672548.5435124	total: 30.8s	remaining: 2m 20s
# 90:	learn: 670825.1872618	total: 31.1s	remaining: 2m 19s
# 91:	learn: 668245.6016068	total: 31.6s	remaining: 2m 19s
# 92:	learn: 665821.9127557	total: 31.9s	remaining: 2m 19s
# 93:	learn: 662555.1244833	total: 32.2s	remaining: 2m 19s
# 94:	learn: 658185.9715816	total: 32.5s	remaining: 2m 18s
# 95:	learn: 655742.4014954	total: 32.7s	remaining: 2m 17s
# 96:	learn: 652544.8951289	total: 33.1s	remaining: 2m 17s
# 97:	learn: 651003.8527847	total: 33.3s	remaining: 2m 16s
# 98:	learn: 650707.0017194	total: 33.4s	remaining: 2m 15s
# 99:	learn: 647790.3816729	total: 33.8s	remaining: 2m 15s
# 100:	learn: 645303.2054662	total: 34.1s	remaining: 2m 14s
# 101:	learn: 643047.4182536	total: 34.4s	remaining: 2m 14s
# 102:	learn: 640663.8534467	total: 34.8s	remaining: 2m 14s
# 103:	learn: 637041.3942339	total: 35.1s	remaining: 2m 13s
# 104:	learn: 635773.5120342	total: 35.5s	remaining: 2m 13s
# 105:	learn: 632128.2228761	total: 35.7s	remaining: 2m 12s
# 106:	learn: 628595.6880534	total: 36.1s	remaining: 2m 12s
# 107:	learn: 626242.7862565	total: 36.4s	remaining: 2m 12s
# 108:	learn: 624312.2376945	total: 36.6s	remaining: 2m 11s
# 109:	learn: 623486.1771255	total: 37s	remaining: 2m 11s
# 110:	learn: 622033.0702520	total: 37.3s	remaining: 2m 10s
# 111:	learn: 620312.2065862	total: 37.7s	remaining: 2m 10s
# 112:	learn: 619574.8772821	total: 38s	remaining: 2m 10s
# 113:	learn: 616229.8769749	total: 38.4s	remaining: 2m 9s
# 114:	learn: 614059.1900796	total: 38.8s	remaining: 2m 9s
# 115:	learn: 612166.1055073	total: 39.2s	remaining: 2m 9s
# 116:	learn: 611099.4453774	total: 39.6s	remaining: 2m 9s
# 117:	learn: 610537.5747537	total: 39.9s	remaining: 2m 9s
# 118:	learn: 608144.8452156	total: 40.3s	remaining: 2m 8s
# 119:	learn: 605430.1287845	total: 40.6s	remaining: 2m 8s
# 120:	learn: 603953.7952355	total: 40.9s	remaining: 2m 8s
# 121:	learn: 602318.5564579	total: 41.3s	remaining: 2m 7s
# 122:	learn: 600205.2047818	total: 41.6s	remaining: 2m 7s
# 123:	learn: 598614.2866404	total: 41.9s	remaining: 2m 7s
# 124:	learn: 595576.1390007	total: 42.3s	remaining: 2m 6s
# 125:	learn: 593850.6958507	total: 42.7s	remaining: 2m 6s
# 126:	learn: 591640.5344222	total: 43s	remaining: 2m 6s
# 127:	learn: 590790.9620173	total: 43.4s	remaining: 2m 6s
# 128:	learn: 588774.0840778	total: 43.8s	remaining: 2m 5s
# 129:	learn: 587146.0576950	total: 44.1s	remaining: 2m 5s
# 130:	learn: 586187.3048927	total: 44.5s	remaining: 2m 5s
# 131:	learn: 584602.2896053	total: 44.8s	remaining: 2m 4s
# 132:	learn: 584194.1622454	total: 45.2s	remaining: 2m 4s
# 133:	learn: 582487.4879920	total: 45.5s	remaining: 2m 4s
# 134:	learn: 580481.8478401	total: 45.9s	remaining: 2m 4s
# 135:	learn: 578751.5983610	total: 46.2s	remaining: 2m 3s
# 136:	learn: 577086.7771295	total: 46.6s	remaining: 2m 3s
# 137:	learn: 576132.8784719	total: 47s	remaining: 2m 3s
# 138:	learn: 573527.0304132	total: 47.3s	remaining: 2m 2s
# 139:	learn: 570134.7538787	total: 47.7s	remaining: 2m 2s
# 140:	learn: 567800.8867319	total: 48s	remaining: 2m 2s
# 141:	learn: 565895.9216184	total: 48.3s	remaining: 2m 1s
# 142:	learn: 564921.7533060	total: 48.6s	remaining: 2m 1s
# 143:	learn: 563793.6378497	total: 49s	remaining: 2m 1s
# 144:	learn: 562209.4244074	total: 49.3s	remaining: 2m
# 145:	learn: 561403.3125900	total: 49.7s	remaining: 2m
# 146:	learn: 559535.8913724	total: 50s	remaining: 2m
# 147:	learn: 557648.3832728	total: 50.3s	remaining: 1m 59s
# 148:	learn: 554974.9397205	total: 50.7s	remaining: 1m 59s
# 149:	learn: 553620.9605900	total: 51s	remaining: 1m 58s
# 150:	learn: 552016.6832084	total: 51.2s	remaining: 1m 58s
# 151:	learn: 550930.0646584	total: 51.6s	remaining: 1m 58s
# 152:	learn: 548464.6734105	total: 51.9s	remaining: 1m 57s
# 153:	learn: 546721.7407147	total: 52.2s	remaining: 1m 57s
# 154:	learn: 544596.7700198	total: 52.5s	remaining: 1m 56s
# 155:	learn: 543333.8976708	total: 52.8s	remaining: 1m 56s
# 156:	learn: 541287.8645607	total: 53.2s	remaining: 1m 56s
# 157:	learn: 540447.6195797	total: 53.5s	remaining: 1m 55s
# 158:	learn: 538829.3362004	total: 53.8s	remaining: 1m 55s
# 159:	learn: 536667.1677793	total: 54.2s	remaining: 1m 55s
# 160:	learn: 534907.9088287	total: 54.5s	remaining: 1m 54s
# 161:	learn: 532348.9728304	total: 54.9s	remaining: 1m 54s
# 162:	learn: 530822.6595088	total: 55.2s	remaining: 1m 54s
# 163:	learn: 529177.3351332	total: 55.5s	remaining: 1m 53s
# 164:	learn: 527666.0528291	total: 55.8s	remaining: 1m 53s
# 165:	learn: 525727.8269138	total: 56.1s	remaining: 1m 52s
# 166:	learn: 525125.3178188	total: 56.5s	remaining: 1m 52s
# 167:	learn: 523936.1387243	total: 56.7s	remaining: 1m 52s
# 168:	learn: 522892.0217704	total: 57.1s	remaining: 1m 51s
# 169:	learn: 521989.4178912	total: 57.4s	remaining: 1m 51s
# 170:	learn: 519891.7304527	total: 57.7s	remaining: 1m 51s
# 171:	learn: 517723.7974733	total: 58.1s	remaining: 1m 50s
# 172:	learn: 515906.4078198	total: 58.4s	remaining: 1m 50s
# 173:	learn: 514427.5331751	total: 58.7s	remaining: 1m 49s
# 174:	learn: 513508.8093828	total: 59.1s	remaining: 1m 49s
# 175:	learn: 511710.2915992	total: 59.4s	remaining: 1m 49s
# 176:	learn: 510258.2627759	total: 59.7s	remaining: 1m 48s
# 177:	learn: 509131.5142221	total: 1m	remaining: 1m 48s
# 178:	learn: 507666.2397499	total: 1m	remaining: 1m 48s
# 179:	learn: 507015.4897381	total: 1m 1s	remaining: 1m 48s
# 180:	learn: 505962.0181057	total: 1m 1s	remaining: 1m 48s
# 181:	learn: 504074.4022244	total: 1m 2s	remaining: 1m 48s
# 182:	learn: 503105.3270615	total: 1m 2s	remaining: 1m 48s
# 183:	learn: 501187.6854845	total: 1m 3s	remaining: 1m 48s
# 184:	learn: 500026.4587578	total: 1m 3s	remaining: 1m 47s
# 185:	learn: 498497.7427268	total: 1m 3s	remaining: 1m 47s
# 186:	learn: 496482.6106335	total: 1m 4s	remaining: 1m 47s
# 187:	learn: 494991.1707102	total: 1m 4s	remaining: 1m 46s
# 188:	learn: 493814.1043824	total: 1m 4s	remaining: 1m 46s
# 189:	learn: 492406.8995936	total: 1m 4s	remaining: 1m 45s
# 190:	learn: 490205.1826035	total: 1m 5s	remaining: 1m 45s
# 191:	learn: 488616.7799243	total: 1m 5s	remaining: 1m 45s
# 192:	learn: 487457.0270604	total: 1m 5s	remaining: 1m 44s
# 193:	learn: 486926.9529561	total: 1m 6s	remaining: 1m 44s
# 194:	learn: 485508.5816630	total: 1m 6s	remaining: 1m 44s
# 195:	learn: 483987.4217660	total: 1m 6s	remaining: 1m 43s
# 196:	learn: 483169.8409541	total: 1m 7s	remaining: 1m 43s
# 197:	learn: 482027.4818471	total: 1m 7s	remaining: 1m 43s
# 198:	learn: 480514.4978999	total: 1m 7s	remaining: 1m 42s
# 199:	learn: 479022.3909642	total: 1m 8s	remaining: 1m 42s
# 200:	learn: 477688.8805241	total: 1m 8s	remaining: 1m 42s
# 201:	learn: 476862.5633055	total: 1m 9s	remaining: 1m 42s
# 202:	learn: 475268.6686903	total: 1m 9s	remaining: 1m 42s
# 203:	learn: 473729.6787805	total: 1m 10s	remaining: 1m 41s
# 204:	learn: 472240.0545378	total: 1m 10s	remaining: 1m 41s
# 205:	learn: 470850.9273552	total: 1m 10s	remaining: 1m 41s
# 206:	learn: 470096.7973445	total: 1m 11s	remaining: 1m 40s
# 207:	learn: 469037.9119994	total: 1m 11s	remaining: 1m 40s
# 208:	learn: 466519.0507990	total: 1m 11s	remaining: 1m 40s
# 209:	learn: 465669.5134893	total: 1m 12s	remaining: 1m 39s
# 210:	learn: 464485.6580177	total: 1m 12s	remaining: 1m 39s
# 211:	learn: 463364.6135000	total: 1m 13s	remaining: 1m 39s
# 212:	learn: 462695.4089593	total: 1m 13s	remaining: 1m 38s
# 213:	learn: 461544.8769488	total: 1m 13s	remaining: 1m 38s
# 214:	learn: 460145.3857756	total: 1m 14s	remaining: 1m 38s
# 215:	learn: 459159.4092314	total: 1m 14s	remaining: 1m 38s
# 216:	learn: 458263.2564383	total: 1m 15s	remaining: 1m 38s
# 217:	learn: 456816.0977509	total: 1m 15s	remaining: 1m 37s
# 218:	learn: 454295.7164665	total: 1m 15s	remaining: 1m 37s
# 219:	learn: 453543.8564285	total: 1m 16s	remaining: 1m 37s
# 220:	learn: 452425.4215111	total: 1m 16s	remaining: 1m 36s
# 221:	learn: 451892.6726285	total: 1m 17s	remaining: 1m 36s
# 222:	learn: 451094.1028985	total: 1m 17s	remaining: 1m 36s
# 223:	learn: 449697.7970383	total: 1m 17s	remaining: 1m 36s
# 224:	learn: 448950.9353955	total: 1m 18s	remaining: 1m 35s
# 225:	learn: 447521.8814818	total: 1m 18s	remaining: 1m 35s
# 226:	learn: 446799.4203987	total: 1m 18s	remaining: 1m 34s
# 227:	learn: 446040.2674511	total: 1m 19s	remaining: 1m 34s
# 228:	learn: 444629.3488509	total: 1m 19s	remaining: 1m 34s
# 229:	learn: 443531.1018285	total: 1m 19s	remaining: 1m 33s
# 230:	learn: 442871.7288795	total: 1m 20s	remaining: 1m 33s
# 231:	learn: 440603.9198518	total: 1m 20s	remaining: 1m 33s
# 232:	learn: 439441.4765138	total: 1m 20s	remaining: 1m 32s
# 233:	learn: 438391.0929846	total: 1m 21s	remaining: 1m 32s
# 234:	learn: 436252.6046248	total: 1m 21s	remaining: 1m 31s
# 235:	learn: 435211.0415283	total: 1m 22s	remaining: 1m 31s
# 236:	learn: 434300.5644663	total: 1m 22s	remaining: 1m 31s
# 237:	learn: 433389.9703782	total: 1m 22s	remaining: 1m 31s
# 238:	learn: 432160.8509243	total: 1m 23s	remaining: 1m 31s
# 239:	learn: 431835.6100058	total: 1m 24s	remaining: 1m 31s
# 240:	learn: 430367.9398652	total: 1m 24s	remaining: 1m 30s
# 241:	learn: 429418.6865947	total: 1m 24s	remaining: 1m 30s
# 242:	learn: 428641.2124310	total: 1m 25s	remaining: 1m 30s
# 243:	learn: 428074.1420532	total: 1m 25s	remaining: 1m 29s
# 244:	learn: 427421.4672719	total: 1m 26s	remaining: 1m 29s
# 245:	learn: 426028.6997346	total: 1m 26s	remaining: 1m 29s
# 246:	learn: 424493.8485525	total: 1m 26s	remaining: 1m 28s
# 247:	learn: 423662.4538607	total: 1m 27s	remaining: 1m 28s
# 248:	learn: 422989.1929018	total: 1m 27s	remaining: 1m 28s
# 249:	learn: 422234.5536763	total: 1m 27s	remaining: 1m 27s
# 250:	learn: 421744.2850847	total: 1m 28s	remaining: 1m 27s
# 251:	learn: 419787.2620501	total: 1m 28s	remaining: 1m 27s
# 252:	learn: 418996.6461689	total: 1m 29s	remaining: 1m 27s
# 253:	learn: 417765.2188785	total: 1m 29s	remaining: 1m 26s
# 254:	learn: 416566.8926353	total: 1m 29s	remaining: 1m 26s
# 255:	learn: 415224.5605796	total: 1m 30s	remaining: 1m 26s
# 256:	learn: 413411.3881524	total: 1m 30s	remaining: 1m 25s
# 257:	learn: 412287.3820680	total: 1m 31s	remaining: 1m 25s
# 258:	learn: 411366.8477584	total: 1m 31s	remaining: 1m 25s
# 259:	learn: 411006.6479595	total: 1m 31s	remaining: 1m 24s
# 260:	learn: 410176.1379660	total: 1m 32s	remaining: 1m 24s
# 261:	learn: 409655.3441194	total: 1m 32s	remaining: 1m 24s
# 262:	learn: 408612.6721798	total: 1m 32s	remaining: 1m 23s
# 263:	learn: 407478.2866583	total: 1m 33s	remaining: 1m 23s
# 264:	learn: 406228.2337476	total: 1m 33s	remaining: 1m 23s
# 265:	learn: 405523.4531012	total: 1m 34s	remaining: 1m 22s
# 266:	learn: 403757.7743018	total: 1m 34s	remaining: 1m 22s
# 267:	learn: 403061.4715348	total: 1m 34s	remaining: 1m 22s
# 268:	learn: 402196.5499317	total: 1m 35s	remaining: 1m 21s
# 269:	learn: 401350.7930891	total: 1m 35s	remaining: 1m 21s
# 270:	learn: 401290.9234990	total: 1m 35s	remaining: 1m 20s
# 271:	learn: 400218.1982976	total: 1m 36s	remaining: 1m 20s
# 272:	learn: 399489.8998107	total: 1m 36s	remaining: 1m 20s
# 273:	learn: 398747.2091361	total: 1m 36s	remaining: 1m 19s
# 274:	learn: 397752.0564687	total: 1m 37s	remaining: 1m 19s
# 275:	learn: 396717.6133703	total: 1m 37s	remaining: 1m 19s
# 276:	learn: 395923.0265908	total: 1m 38s	remaining: 1m 19s
# 277:	learn: 394836.4772467	total: 1m 38s	remaining: 1m 18s
# 278:	learn: 393979.3985416	total: 1m 39s	remaining: 1m 18s
# 279:	learn: 392798.3598905	total: 1m 39s	remaining: 1m 18s
# 280:	learn: 391468.3116098	total: 1m 39s	remaining: 1m 17s
# 281:	learn: 389538.9253841	total: 1m 39s	remaining: 1m 17s
# 282:	learn: 388492.4813003	total: 1m 40s	remaining: 1m 16s
# 283:	learn: 388038.4520365	total: 1m 40s	remaining: 1m 16s
# 284:	learn: 386654.4062372	total: 1m 41s	remaining: 1m 16s
# 285:	learn: 385708.3922515	total: 1m 41s	remaining: 1m 15s
# 286:	learn: 385235.0516245	total: 1m 41s	remaining: 1m 15s
# 287:	learn: 384289.1936161	total: 1m 42s	remaining: 1m 15s
# 288:	learn: 383510.1617161	total: 1m 42s	remaining: 1m 14s
# 289:	learn: 382900.8148722	total: 1m 43s	remaining: 1m 14s
# 290:	learn: 382474.2216709	total: 1m 43s	remaining: 1m 14s
# 291:	learn: 381502.7797480	total: 1m 44s	remaining: 1m 14s
# 292:	learn: 380396.6069190	total: 1m 44s	remaining: 1m 13s
# 293:	learn: 379330.0921949	total: 1m 44s	remaining: 1m 13s
# 294:	learn: 378077.5665657	total: 1m 45s	remaining: 1m 13s
# 295:	learn: 377402.7259399	total: 1m 45s	remaining: 1m 12s
# 296:	learn: 376483.7824779	total: 1m 46s	remaining: 1m 12s
# 297:	learn: 375916.1490675	total: 1m 46s	remaining: 1m 12s
# 298:	learn: 374563.9669039	total: 1m 46s	remaining: 1m 11s
# 299:	learn: 374123.3834780	total: 1m 47s	remaining: 1m 11s
# 300:	learn: 373554.9980857	total: 1m 47s	remaining: 1m 11s
# 301:	learn: 373063.2199346	total: 1m 47s	remaining: 1m 10s
# 302:	learn: 372387.5353521	total: 1m 48s	remaining: 1m 10s
# 303:	learn: 370855.9123633	total: 1m 48s	remaining: 1m 10s
# 304:	learn: 370119.1199558	total: 1m 48s	remaining: 1m 9s
# 305:	learn: 369219.3325014	total: 1m 49s	remaining: 1m 9s
# 306:	learn: 368327.6696836	total: 1m 49s	remaining: 1m 8s
# 307:	learn: 368109.5340277	total: 1m 49s	remaining: 1m 8s
# 308:	learn: 367513.1716146	total: 1m 50s	remaining: 1m 8s
# 309:	learn: 366906.8406742	total: 1m 50s	remaining: 1m 7s
# 310:	learn: 365862.6374729	total: 1m 51s	remaining: 1m 7s
# 311:	learn: 365625.7979740	total: 1m 51s	remaining: 1m 7s
# 312:	learn: 364469.2364941	total: 1m 51s	remaining: 1m 6s
# 313:	learn: 363449.6637013	total: 1m 52s	remaining: 1m 6s
# 314:	learn: 362937.7978409	total: 1m 52s	remaining: 1m 6s
# 315:	learn: 362370.7635354	total: 1m 52s	remaining: 1m 5s
# 316:	learn: 361756.2699599	total: 1m 53s	remaining: 1m 5s
# 317:	learn: 360647.6357873	total: 1m 53s	remaining: 1m 5s
# 318:	learn: 359461.4771602	total: 1m 53s	remaining: 1m 4s
# 319:	learn: 358710.4560888	total: 1m 54s	remaining: 1m 4s
# 320:	learn: 357767.6321981	total: 1m 54s	remaining: 1m 4s
# 321:	learn: 357266.1715203	total: 1m 55s	remaining: 1m 3s
# 322:	learn: 356370.4204132	total: 1m 55s	remaining: 1m 3s
# 323:	learn: 355871.2229355	total: 1m 55s	remaining: 1m 2s
# 324:	learn: 355149.4650847	total: 1m 56s	remaining: 1m 2s
# 325:	learn: 354723.5157599	total: 1m 56s	remaining: 1m 2s
# 326:	learn: 353949.6359670	total: 1m 57s	remaining: 1m 1s
# 327:	learn: 353480.3051717	total: 1m 57s	remaining: 1m 1s
# 328:	learn: 352669.5604623	total: 1m 57s	remaining: 1m 1s
# 329:	learn: 352205.0117832	total: 1m 58s	remaining: 1m
# 330:	learn: 351515.4801840	total: 1m 58s	remaining: 1m
# 331:	learn: 350669.1923585	total: 1m 58s	remaining: 1m
# 332:	learn: 349638.2200846	total: 1m 59s	remaining: 59.8s
# 333:	learn: 348760.4564384	total: 1m 59s	remaining: 59.5s
# 334:	learn: 348218.4479619	total: 2m	remaining: 59.1s
# 335:	learn: 347277.6532008	total: 2m	remaining: 58.8s
# 336:	learn: 346568.5922866	total: 2m	remaining: 58.4s
# 337:	learn: 346100.2408614	total: 2m 1s	remaining: 58s
# 338:	learn: 345446.7060373	total: 2m 1s	remaining: 57.7s
# 339:	learn: 344376.7549260	total: 2m 1s	remaining: 57.3s
# 340:	learn: 344183.5052618	total: 2m 2s	remaining: 56.9s
# 341:	learn: 343453.4896657	total: 2m 2s	remaining: 56.6s
# 342:	learn: 342377.1949298	total: 2m 2s	remaining: 56.2s
# 343:	learn: 342058.7596285	total: 2m 3s	remaining: 55.9s
# 344:	learn: 341296.1321252	total: 2m 3s	remaining: 55.5s
# 345:	learn: 340370.2491609	total: 2m 3s	remaining: 55.2s
# 346:	learn: 339241.6557503	total: 2m 4s	remaining: 54.8s
# 347:	learn: 338615.1472123	total: 2m 4s	remaining: 54.4s
# 348:	learn: 337851.9774694	total: 2m 5s	remaining: 54.1s
# 349:	learn: 337436.1396841	total: 2m 5s	remaining: 53.7s
# 350:	learn: 337093.5949880	total: 2m 5s	remaining: 53.4s
# 351:	learn: 336900.9054906	total: 2m 6s	remaining: 53s
# 352:	learn: 336055.9223987	total: 2m 6s	remaining: 52.6s
# 353:	learn: 335177.5605496	total: 2m 6s	remaining: 52.3s
# 354:	learn: 334799.5116802	total: 2m 7s	remaining: 51.9s
# 355:	learn: 334276.3620843	total: 2m 7s	remaining: 51.6s
# 356:	learn: 333259.1555066	total: 2m 7s	remaining: 51.2s
# 357:	learn: 332582.2364226	total: 2m 8s	remaining: 50.8s
# 358:	learn: 332093.7029395	total: 2m 8s	remaining: 50.5s
# 359:	learn: 331221.5841683	total: 2m 9s	remaining: 50.2s
# 360:	learn: 330612.0058292	total: 2m 9s	remaining: 49.8s
# 361:	learn: 330187.6308139	total: 2m 9s	remaining: 49.4s
# 362:	learn: 328952.1022448	total: 2m 9s	remaining: 49.1s
# 363:	learn: 328919.5880441	total: 2m 10s	remaining: 48.7s
# 364:	learn: 328545.1204428	total: 2m 10s	remaining: 48.3s
# 365:	learn: 327943.2959172	total: 2m 11s	remaining: 48s
# 366:	learn: 327646.9493165	total: 2m 11s	remaining: 47.7s
# 367:	learn: 327575.9734340	total: 2m 11s	remaining: 47.3s
# 368:	learn: 326936.8405216	total: 2m 12s	remaining: 46.9s
# 369:	learn: 326110.2337335	total: 2m 12s	remaining: 46.5s
# 370:	learn: 325426.5076409	total: 2m 12s	remaining: 46.2s
# 371:	learn: 324763.0821869	total: 2m 13s	remaining: 45.9s
# 372:	learn: 324411.5248906	total: 2m 13s	remaining: 45.6s
# 373:	learn: 323817.8816264	total: 2m 14s	remaining: 45.3s
# 374:	learn: 323469.6228556	total: 2m 14s	remaining: 44.9s
# 375:	learn: 322785.9889706	total: 2m 15s	remaining: 44.6s
# 376:	learn: 322089.1391946	total: 2m 15s	remaining: 44.2s
# 377:	learn: 321210.7877455	total: 2m 15s	remaining: 43.9s
# 378:	learn: 320862.4381645	total: 2m 16s	remaining: 43.6s
# 379:	learn: 320281.5611633	total: 2m 16s	remaining: 43.2s
# 380:	learn: 319747.6475967	total: 2m 17s	remaining: 42.8s
# 381:	learn: 318386.4173053	total: 2m 17s	remaining: 42.5s
# 382:	learn: 317555.6455235	total: 2m 17s	remaining: 42.1s
# 383:	learn: 317125.5830332	total: 2m 18s	remaining: 41.8s
# 384:	learn: 316562.9220187	total: 2m 18s	remaining: 41.4s
# 385:	learn: 315432.0648006	total: 2m 19s	remaining: 41.1s
# 386:	learn: 314508.8226787	total: 2m 19s	remaining: 40.7s
# 387:	learn: 313899.9443742	total: 2m 19s	remaining: 40.4s
# 388:	learn: 313453.9568886	total: 2m 20s	remaining: 40s
# 389:	learn: 312440.0357879	total: 2m 20s	remaining: 39.7s
# 390:	learn: 311815.5472828	total: 2m 20s	remaining: 39.3s
# 391:	learn: 310948.5209007	total: 2m 21s	remaining: 38.9s
# 392:	learn: 310572.3694887	total: 2m 21s	remaining: 38.6s
# 393:	learn: 310084.0010999	total: 2m 21s	remaining: 38.2s
# 394:	learn: 309585.5279064	total: 2m 22s	remaining: 37.9s
# 395:	learn: 308924.3957073	total: 2m 22s	remaining: 37.5s
# 396:	learn: 308567.1997035	total: 2m 23s	remaining: 37.1s
# 397:	learn: 307512.4356349	total: 2m 23s	remaining: 36.8s
# 398:	learn: 306904.2728181	total: 2m 23s	remaining: 36.4s
# 399:	learn: 305959.1893610	total: 2m 24s	remaining: 36.1s
# 400:	learn: 304775.4928138	total: 2m 24s	remaining: 35.7s
# 401:	learn: 304208.0149979	total: 2m 24s	remaining: 35.3s
# 402:	learn: 303571.3245841	total: 2m 25s	remaining: 35s
# 403:	learn: 302909.1918251	total: 2m 25s	remaining: 34.6s
# 404:	learn: 302420.1791695	total: 2m 26s	remaining: 34.3s
# 405:	learn: 302115.6464293	total: 2m 26s	remaining: 33.9s
# 406:	learn: 301233.2249603	total: 2m 26s	remaining: 33.5s
# 407:	learn: 299976.2860100	total: 2m 27s	remaining: 33.2s
# 408:	learn: 299512.1500009	total: 2m 27s	remaining: 32.8s
# 409:	learn: 298927.8543991	total: 2m 27s	remaining: 32.5s
# 410:	learn: 298161.8622263	total: 2m 28s	remaining: 32.1s
# 411:	learn: 297059.4079245	total: 2m 28s	remaining: 31.7s
# 412:	learn: 296515.7293706	total: 2m 28s	remaining: 31.4s
# 413:	learn: 295574.3144077	total: 2m 29s	remaining: 31s
# 414:	learn: 294796.7943303	total: 2m 29s	remaining: 30.7s
# 415:	learn: 294071.8016847	total: 2m 30s	remaining: 30.3s
# 416:	learn: 293663.5915454	total: 2m 30s	remaining: 29.9s
# 417:	learn: 292597.0001597	total: 2m 30s	remaining: 29.6s
# 418:	learn: 291976.9120215	total: 2m 31s	remaining: 29.2s
# 419:	learn: 291346.4164053	total: 2m 31s	remaining: 28.8s
# 420:	learn: 291094.7074780	total: 2m 31s	remaining: 28.5s
# 421:	learn: 290749.6427641	total: 2m 32s	remaining: 28.1s
# 422:	learn: 290098.4861878	total: 2m 32s	remaining: 27.7s
# 423:	learn: 289347.1586158	total: 2m 32s	remaining: 27.4s
# 424:	learn: 288992.5057835	total: 2m 33s	remaining: 27s
# 425:	learn: 288501.5673146	total: 2m 33s	remaining: 26.6s
# 426:	learn: 288124.6051738	total: 2m 33s	remaining: 26.3s
# 427:	learn: 287503.0400094	total: 2m 34s	remaining: 25.9s
# 428:	learn: 287094.4660275	total: 2m 34s	remaining: 25.6s
# 429:	learn: 286107.7910908	total: 2m 34s	remaining: 25.2s
# 430:	learn: 285291.5062592	total: 2m 35s	remaining: 24.8s
# 431:	learn: 284930.9227317	total: 2m 35s	remaining: 24.5s
# 432:	learn: 284351.1385554	total: 2m 35s	remaining: 24.1s
# 433:	learn: 283490.6026984	total: 2m 36s	remaining: 23.8s
# 434:	learn: 282536.5041240	total: 2m 36s	remaining: 23.4s
# 435:	learn: 282077.7842067	total: 2m 36s	remaining: 23s
# 436:	learn: 281496.4436563	total: 2m 37s	remaining: 22.7s
# 437:	learn: 280846.0751728	total: 2m 37s	remaining: 22.3s
# 438:	learn: 280351.2159344	total: 2m 37s	remaining: 21.9s
# 439:	learn: 279663.6447612	total: 2m 38s	remaining: 21.6s
# 440:	learn: 278977.1071589	total: 2m 38s	remaining: 21.2s
# 441:	learn: 277977.3367079	total: 2m 39s	remaining: 20.9s
# 442:	learn: 277367.9302407	total: 2m 39s	remaining: 20.5s
# 443:	learn: 276331.9613551	total: 2m 39s	remaining: 20.2s
# 444:	learn: 276087.2792734	total: 2m 40s	remaining: 19.8s
# 445:	learn: 275473.7555022	total: 2m 40s	remaining: 19.4s
# 446:	learn: 275027.3289795	total: 2m 41s	remaining: 19.1s
# 447:	learn: 274487.1726580	total: 2m 41s	remaining: 18.7s
# 448:	learn: 274105.2255086	total: 2m 41s	remaining: 18.4s
# 449:	learn: 273746.2980140	total: 2m 42s	remaining: 18s
# 450:	learn: 273262.3305425	total: 2m 42s	remaining: 17.7s
# 451:	learn: 272145.5067603	total: 2m 43s	remaining: 17.4s
# 452:	learn: 271595.9801339	total: 2m 43s	remaining: 17s
# 453:	learn: 271017.7710400	total: 2m 44s	remaining: 16.6s
# 454:	learn: 270531.2489060	total: 2m 44s	remaining: 16.3s
# 455:	learn: 270165.6695188	total: 2m 44s	remaining: 15.9s
# 456:	learn: 269748.4439961	total: 2m 45s	remaining: 15.6s
# 457:	learn: 269103.9518535	total: 2m 45s	remaining: 15.2s
# 458:	learn: 268638.6903348	total: 2m 46s	remaining: 14.9s
# 459:	learn: 268075.2671146	total: 2m 46s	remaining: 14.5s
# 460:	learn: 267244.7158495	total: 2m 47s	remaining: 14.1s
# 461:	learn: 266630.9132091	total: 2m 47s	remaining: 13.8s
# 462:	learn: 265895.2382501	total: 2m 48s	remaining: 13.5s
# 463:	learn: 265086.0962107	total: 2m 48s	remaining: 13.1s
# 464:	learn: 264205.7079051	total: 2m 49s	remaining: 12.8s
# 465:	learn: 263481.4982339	total: 2m 50s	remaining: 12.4s
# 466:	learn: 262961.3910819	total: 2m 50s	remaining: 12.1s
# 467:	learn: 262555.8052713	total: 2m 51s	remaining: 11.7s
# 468:	learn: 261713.2690128	total: 2m 51s	remaining: 11.4s
# 469:	learn: 260565.9058496	total: 2m 52s	remaining: 11s
# 470:	learn: 260078.4901217	total: 2m 52s	remaining: 10.6s
# 471:	learn: 258841.4085877	total: 2m 53s	remaining: 10.3s
# 472:	learn: 258088.9732218	total: 2m 53s	remaining: 9.9s
# 473:	learn: 257339.4863919	total: 2m 53s	remaining: 9.54s
# 474:	learn: 256967.9048651	total: 2m 54s	remaining: 9.17s
# 475:	learn: 256340.0165591	total: 2m 54s	remaining: 8.81s
# 476:	learn: 255872.2364472	total: 2m 55s	remaining: 8.44s
# 477:	learn: 255188.3966497	total: 2m 55s	remaining: 8.09s
# 478:	learn: 254964.1360499	total: 2m 56s	remaining: 7.72s
# 479:	learn: 254441.7699889	total: 2m 56s	remaining: 7.36s
# 480:	learn: 254182.5857626	total: 2m 56s	remaining: 6.99s
# 481:	learn: 253779.2267201	total: 2m 57s	remaining: 6.62s
# 482:	learn: 253728.4454491	total: 2m 57s	remaining: 6.25s
# 483:	learn: 253382.3223302	total: 2m 58s	remaining: 5.89s
# 484:	learn: 252841.0958866	total: 2m 58s	remaining: 5.53s
# 485:	learn: 252373.5483461	total: 2m 59s	remaining: 5.16s
# 486:	learn: 252078.3605541	total: 2m 59s	remaining: 4.8s
# 487:	learn: 251500.1174659	total: 3m	remaining: 4.43s
# 488:	learn: 251161.1554177	total: 3m	remaining: 4.06s
# 489:	learn: 250693.8603493	total: 3m	remaining: 3.69s
# 490:	learn: 250205.9197749	total: 3m 1s	remaining: 3.32s
# 491:	learn: 249449.1679404	total: 3m 1s	remaining: 2.95s
# 492:	learn: 248479.3189660	total: 3m 1s	remaining: 2.58s
# 493:	learn: 247873.6204445	total: 3m 2s	remaining: 2.21s
# 494:	learn: 247407.5949365	total: 3m 2s	remaining: 1.85s
# 495:	learn: 247095.2602019	total: 3m 3s	remaining: 1.48s
# 496:	learn: 246820.6972466	total: 3m 3s	remaining: 1.11s
# 497:	learn: 246107.6021810	total: 3m 4s	remaining: 739ms
# 498:	learn: 245620.1882641	total: 3m 4s	remaining: 370ms
# 499:	learn: 244930.7231400	total: 3m 5s	remaining: 0us
# 474517.92021225754

# %% [markdown]
# # Обучаем регрессор на всем трейне,  фитим на тестовой выборке, затем записываем данные в .csv

# %%
# cb_regressor.fit(preprocessed_train_data, y_train, cat_features=cat_features)
# cb_predict = cb_regressor.predict(preprocessed_test_data)
# df = pd.DataFrame({'id': np.arange(1e5, 1e5 + test_data.shape[0], dtype=int), 'price': cb_predict})
# df.to_csv('submission_15.csv', index=False)
